# %%
from google.colab import files
files.upload ()
# Out:
#      <input type="file" id="files-34849ca4-b8cf-4420-a8e8-8868f37ff179" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34849ca4-b8cf-4420-a8e8-8868f37ff179">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
diabetes=pd.read_csv('dataDiabetes.csv')
print(diabetes.head)
# Out:
# <bound method NDFrame.head of      pregnant  glucose  pressure  triceps  insulin  mass  pedigree  age  \
# 0           1       89        66       23       94  28.1     0.167   21
# 1           0      137        40       35      168  43.1     2.288   33
# 2           3       78        50       32       88  31.0     0.248   26
# 3           2      197        70       45      543  30.5     0.158   53
# 4           1      189        60       23      846  30.1     0.398   59
# ..        ...      ...       ...      ...      ...   ...       ...  ...
# 387         0      181        88       44      510  43.3     0.222   26
# 388         1      128        88       39      110  36.5     1.057   37
# 389         2       88        58       26       16  28.4     0.766   22
# 390        10      101        76       48      180  32.9     0.171   63
# 391         5      121        72       23      112  26.2     0.245   30
#
#     diabetes
# 0        neg
# 1        pos
# 2        pos
# 3        pos
# ...

# %%
# !pip install  -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth=GoogleAuth()
gauth.credentials=GoogleCredentials.get_application_default()
drive=GoogleDrive(gauth)

# %%
downloaded=drive.CreateFile({'id':'11v6cSov87X6gIzq0tjMTPyoXBriJJYQf'})
downloaded.GetContentFile(' dataDiabetes.csv ')

import pandas as pd
diabetes=pd.read_csv('dataDiabetes.csv')
print(diabetes)
diabetes.columns
# Out:
#      pregnant  glucose  pressure  triceps  insulin  mass  pedigree  age  \
# 0           1       89        66       23       94  28.1     0.167   21
# 1           0      137        40       35      168  43.1     2.288   33
# 2           3       78        50       32       88  31.0     0.248   26
# 3           2      197        70       45      543  30.5     0.158   53
# 4           1      189        60       23      846  30.1     0.398   59
# ..        ...      ...       ...      ...      ...   ...       ...  ...
# 387         0      181        88       44      510  43.3     0.222   26
# 388         1      128        88       39      110  36.5     1.057   37
# 389         2       88        58       26       16  28.4     0.766   22
# 390        10      101        76       48      180  32.9     0.171   63
# 391         5      121        72       23      112  26.2     0.245   30
#
#     diabetes
# 0        neg
# 1        pos
# 2        pos
# 3        pos
# 4        pos
# ..       ...
# ...

# %%
import pandas as pd
import plotly.express as px
fig=px.scatter_3d(diabetes, x='diabetes', y= 'triceps', z='age', color='age')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
fig=px.scatter_3d(diabetes, x='glucose', y= 'pressure', z='insulin', color='mass')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
fig=px.scatter_3d(diabetes, x='mass', y= 'pedigree', z='diabetes', color='mass')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
fig=px.scatter_3d(diabetes, x='pressure', y= 'pedigree', z='glucose', color='glucose')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
fig=px.scatter_3d(diabetes, x='age', y= 'insulin', z='triceps', color='insulin')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
datos.describe
# Out:
# <bound method NDFrame.describe of      pregnant  glucose  pressure  triceps  insulin  mass  pedigree  age  \
# 0           1       89        66       23       94  28.1     0.167   21
# 1           0      137        40       35      168  43.1     2.288   33
# 2           3       78        50       32       88  31.0     0.248   26
# 3           2      197        70       45      543  30.5     0.158   53
# 4           1      189        60       23      846  30.1     0.398   59
# ..        ...      ...       ...      ...      ...   ...       ...  ...
# 387         0      181        88       44      510  43.3     0.222   26
# 388         1      128        88       39      110  36.5     1.057   37
# 389         2       88        58       26       16  28.4     0.766   22
# 390        10      101        76       48      180  32.9     0.171   63
# 391         5      121        72       23      112  26.2     0.245   30
#
#     diabetes
# 0        neg
# 1        pos
# 2        pos
# ...

# %%
datos.iloc[0:5, 0:6]
# Out:
#    pregnant  glucose  pressure  triceps  insulin  mass
# 0         1       89        66       23       94  28.1
# 1         0      137        40       35      168  43.1
# 2         3       78        50       32       88  31.0
# 3         2      197        70       45      543  30.5
# 4         1      189        60       23      846  30.1
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_13, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
# ...

# %%
datos.describe()
# Out:
#          pregnant     glucose    pressure     triceps     insulin        mass  \
# count  392.000000  392.000000  392.000000  392.000000  392.000000  392.000000
# mean     3.301020  122.627551   70.663265   29.145408  156.056122   33.086224
# std      3.211424   30.860781   12.496092   10.516424  118.841690    7.027659
# min      0.000000   56.000000   24.000000    7.000000   14.000000   18.200000
# 25%      1.000000   99.000000   62.000000   21.000000   76.750000   28.400000
# 50%      2.000000  119.000000   70.000000   29.000000  125.500000   33.200000
# 75%      5.000000  143.000000   78.000000   37.000000  190.000000   37.100000
# max     17.000000  198.000000  110.000000   63.000000  846.000000   67.100000
#
#          pedigree         age
# count  392.000000  392.000000
# mean     0.523046   30.864796
# std      0.345488   10.200777
# min      0.085000   21.000000
# 25%      0.269750   23.000000
# 50%      0.449500   27.000000
# 75%      0.687000   36.000000
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pregnant  392 non-null    int64
#  1   glucose   392 non-null    int64
#  2   pressure  392 non-null    int64
#  3   triceps   392 non-null    int64
#  4   insulin   392 non-null    int64
#  5   mass      392 non-null    float64
#  6   pedigree  392 non-null    float64
#  7   age       392 non-null    int64
#  8   diabetes  392 non-null    object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 27.7+ KB

# %%
datos.isnull().sum()
# Out:
# pregnant    0
# glucose     0
# pressure    0
# triceps     0
# insulin     0
# mass        0
# pedigree    0
# age         0
# diabetes    0
# dtype: int64

# %%
datos.isnull().any()
# Out:
# pregnant    False
# glucose     False
# pressure    False
# triceps     False
# insulin     False
# mass        False
# pedigree    False
# age         False
# diabetes    False
# dtype: bool
